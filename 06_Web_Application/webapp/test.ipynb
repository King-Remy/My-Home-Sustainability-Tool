# %%
from views.calculationHelpers import helper
# from views.predictionHelper import MLhelper
import pandas as pd
import xgboost as xgb

# %%
formData = {'projectName': 'Project 5', 'propertyAddress': 'Stoke on Trent', 'postCode': 'ST5 1LZ', 'propertyType': 'Detached', 'projectLocation': 'Northern Ireland', 'propertyAge': 'Built 2003 or later', 'extensionCount': '1', 'noofFloors': '33', 'indoorTemperature': '23', 'externalWallType': 'Cavity wall 2002 - 2020', 'energyTarrif': 'Standard Tariff', 'lightingType': 'No low energy lighting', 'noofRooms': '1', 'hotwaterHeating': 'Oil Boiler', 'mainHeatingControls': 'Programmer: time control',
    'buildingLength': '4', 'buildingWidth': '4', 'extension1Length': '40', 'extension1Width': '04', 'extension2Length': '0', 'extension2Width': '0', 'extension3Length': '0', 'extension3Width': '0', 'roofHeight': '4', 'heightofWall': '4', 'noofWindows': '2', 'windowType': 'Double glazed from 2020', 'windowSize1': 'Small', 'windowSize2': 'Medium', 'noofDoors': '1', 'doorType': 'External', 'doorSize1': 'Small', 'roofConstruction': 'Insulated horizontally from 2021', 'floorType': 'Insulated Timber 1990 above'}

# %%
helperClass = helper()


user = formData['floorType']
floorType = helper.floor_description[user]

# floorResitance = [value == 0 if user in floorType == 'I dont know the floor type' else value ==
#           4 for key, value in floorType.items()]


if user == 'I dont know the floor type':
    floorType == 0
else:
    floorType == 4

print(floorType)
# Out:
# 4

# %%
model = xgb.XGBRegressor()
model.load_model("C:/Users/KingRemy/OneDrive - University of Keele/Documents/SEND/My-Home-Sustaainabilty-Tool-Web-App/webapp/model/MLModels/EnergyEfficiencyTool2.json")

# %%
trained_data = pd.read_csv('C:/Users/KingRemy/OneDrive - University of Keele/Documents/SEND/DATASETS/EPCs/training_data.csv')

# %%
trained_data
# Out:
#          TOTAL_FLOOR_AREA  built_form_Detached  built_form_End-Terrace  \
# 0                   129.0                    0                       1
# 1                    66.0                    0                       0
# 2                   290.0                    0                       1
# 3                   130.0                    0                       1
# 4                    99.0                    0                       0
# ...                   ...                  ...                     ...
# 3867184              77.0                    0                       1
# 3867185              86.0                    0                       0
# 3867186              52.0                    0                       0
# 3867187             123.2                    0                       1
# 3867188              38.0                    0                       0
#
#          built_form_Mid-Terrace  built_form_Other  built_form_Semi-Detached  \
# ...

# %%
col_list = trained_data.columns.values.tolist()
print(col_list)
# Out:
# ['TOTAL_FLOOR_AREA', 'built_form_Detached', 'built_form_End-Terrace', 'built_form_Mid-Terrace', 'built_form_Other', 'built_form_Semi-Detached', 'energy_tariff_Dual', 'energy_tariff_I dont know', 'energy_tariff_Off-Peak', 'energy_tariff_Single', 'energy_tariff_Standard Tariff', 'floor_description_Concrete uninsulated floor pre 1990', 'floor_description_I dont know', 'floor_description_Insulated Timber 1990 above', 'floor_description_Insulated concrete 1990 above', 'floor_description_Timber un-insulated floor pre 1990', 'glazed_type_Double glazed', 'glazed_type_Double glazed from 2020', 'glazed_type_I dont know', 'glazed_type_Single glazed', 'hotwater_description_Coal Boiler', 'hotwater_description_Electric Heating', 'hotwater_description_Electric immersion, off-peak, plus solar, waste water heat recovery', 'hotwater_description_From main heating system, no cylinderstat', 'hotwater_description_Fuel Boiler', 'hotwater_description_Gas Boiler', 'hotwater_description_Gas boiler/circulator,
# ...

# %%
columns =[{'TOTAL_FLOOR_AREA':300.0, 'built_form': 'End-Terrace', 'energy_tariff':'Dual',
                    'floor_description': 'Concrete uninsulated floor pre 1990', 'glazed_type': 'Single glazed', 'hotwater_description': 'Fuel Boiler',
                    'lighting_description': 'I dont know', 'mainheat_controls': 'Community heating charging system', 'property_type': 'One storey building',
                    'roof_description': 'Insulated on the slope from 2002 To 2021', 'transaction_type': 'Private rental', 'walls_description':'Cavity wall 2002 - 2020', 
                    'window_description': 'Double glazed from 2020', 'extension': '1', 
                    'floor_height': '2.3-2.4', 'habitable_rooms': '3', 'open_fireplaces': '1'}]

# %%
energyEfficiency = pd.DataFrame(columns, index = list(range(len(columns))))
raw_column_energyEfficiency = energyEfficiency.columns.values.tolist()

# %%
col_list = trained_data.columns.values.tolist()
template = pd.DataFrame([96 * [None]], columns=col_list)

# for key, value in energyEfficiency.items():
#     print(value)
#     print(key)
#     print(type(energyEfficiency[key]))

for col in raw_column_energyEfficiency:
    if 'TOTAL_FLOOR_AREA' == col:
        if energyEfficiency['TOTAL_FLOOR_AREA'].item() > 0:
            template.loc[0, col] = 1
        else:
            template.loc[0, col] = 0
    elif col in raw_column_energyEfficiency:
        template.loc[0, col + "_" + energyEfficiency.loc[0, col]] = 1
    else:
        template.loc[0, col] = energyEfficiency.loc[0, col]


# replace  Nan with 0
energyEfficiency = template.fillna(0)

counted = len(energyEfficiency.columns.values.tolist())
energyEfficiency
# Out:
#    TOTAL_FLOOR_AREA  built_form_Detached  built_form_End-Terrace  \
# 0                 1                    0                       1
#
#    built_form_Mid-Terrace  built_form_Other  built_form_Semi-Detached  \
# 0                       0                 0                         0
#
#    energy_tariff_Dual  energy_tariff_I dont know  energy_tariff_Off-Peak  \
# 0                   1                          0                       0
#
#    energy_tariff_Single  ...  habitable_rooms_1  habitable_rooms_2  \
# 0                     0  ...                  0                  0
#
#    habitable_rooms_3  habitable_rooms_4  habitable_rooms_5  \
# 0                  1                  0                  0
#
#    habitable_rooms_6+  habitable_rooms_nan  open_fireplaces_0  \
# 0                   0                    0                  0
#
#    open_fireplaces_1  open_fireplaces_2+
# 0                  1                   0
#
# [1 rows x 96 columns]

# %%
# v = energyEfficiency['TOTAL_FLOOR_AREA'].item()
# print(v)
# Out:
# 127.0

# %%
energyEfficiencyPrediction = model.predict(energyEfficiency)
print(round(energyEfficiencyPrediction[0]))
# Out:
# 32

# %%
['TOTAL_FLOOR_AREA', 
'built_form_Detached', 'built_form_End-Terrace', 'built_form_Mid-Terrace', 'built_form_Other', 'built_form_Semi-Detached', 
 'energy_tariff_Dual', 'energy_tariff_I dont know', 'energy_tariff_Off-Peak', 'energy_tariff_Single', 'energy_tariff_Standard Tariff', 
 'floor_description_Concrete uninsulated floor pre 1990', 'floor_description_I dont know', 'floor_description_Insulated Timber 1990 above', 'floor_description_Insulated concrete 1990 above', 'floor_description_Timber un-insulated floor pre 1990', 
 'glazed_type_Double glazed', 'glazed_type_Double glazed from 2020', 'glazed_type_I dont know', 'glazed_type_Single glazed', 
 'hotwater_description_Coal Boiler', 'hotwater_description_Electric Heating', 'hotwater_description_Electric immersion, off-peak, plus solar, waste water heat recovery', 'hotwater_description_From main heating system, no cylinderstat', 'hotwater_description_Fuel Boiler', 'hotwater_description_Gas Boiler', 'hotwater_description_Gas boiler/circulator, waste water heat recovery', 'hotwater_description_No system present: electric immersion assumed, flue gas heat recovery', 'hotwater_description_Oil Boiler', 'hotwater_description_Solar', 
 'lighting_description_I dont know', 'lighting_description_Low energy lighting', 'lighting_description_No low energy lighting', 
 'mainheat_controls_Community heating charging system', 'mainheat_controls_I dont know', 'mainheat_controls_Prgrammer: room thermostat', 'mainheat_controls_Programmer: TRVs', 'mainheat_controls_Programmer: no room thermostat', 'mainheat_controls_Programmer: room thermostat', 'mainheat_controls_Programmer: time control', 'mainheat_controls_Room thermostat', 
 'property_type_Few storey building', 'property_type_Multiple storey building', 'property_type_One storey building', 
 'roof_description_Always, limited insulation', 'roof_description_Central building Regulations: new build', 'roof_description_I dont know', 'roof_description_Insulated horizontally from 1990 to 2002', 'roof_description_Insulated horizontally from 2002 to 2021', 'roof_description_Insulated horizontally from 2021', 'roof_description_Insulated on the slope from 1990 To 2001', 'roof_description_Insulated on the slope from 2002 To 2021', 'roof_description_Insulated on the slope from 2021', 'roof_description_No insulation', 'roof_description_Trawsyriannedd thermol cyfartalog 0.11 W/m²K', 
 'transaction_type_Green deal assessment', 'transaction_type_I dont know', 'transaction_type_New dwelling', 'transaction_type_Private rental', 'transaction_type_Sale', 'transaction_type_Social rental', 'transaction_type_Stock condition survey', 
 'walls_description_Cavity wall 1960 - 1980', 'walls_description_Cavity wall 1980 - 2001', 'walls_description_Cavity wall 2002 - 2020', 'walls_description_Cavity wall from 2021 to present', 'walls_description_Cavity wall, insulated', 'walls_description_I dont know', 'walls_description_No insulation', 'walls_description_average thermal transmittance 4.1 w/m²k', 'walls_description_cob, filled cavity and internal insulation', 'walls_description_trawsyriannedd thermol cyfartalog 0.24 w/m²k', 
 'window_description_Double glazed', 'window_description_Double glazed from 2020', 'window_description_I dont know', 'window_description_Single glazed', 
 'extension_0', 'extension_1', 'extension_2+', 'extension_nan', 
 'floor_height_0-2.3', 'floor_height_2.3-2.4', 'floor_height_2.4-2.5', 'floor_height_2.5', 'floor_height_2.5-2.7', 'floor_height_2.7+', 
 'habitable_rooms_1', 'habitable_rooms_2', 'habitable_rooms_3', 'habitable_rooms_4', 'habitable_rooms_5', 'habitable_rooms_6+', 'habitable_rooms_nan', 
 'open_fireplaces_0', 'open_fireplaces_1', 'open_fireplaces_2+', 'built_form_detached']
