# %% [markdown]
# # CHAID
#
# The EPC data contains several categorical variables with a lot of values. In order to find suitable features which will retain the most information, three feature sets are explored;
# * data driven
# * domain driven
# * exhaustive
#
# The first approach, termed data driven, uses statistical methods to reduce the number of variables. As the variables containing textual descriptions of the property have been created free-hand, many contain a large number of unique values. In some cases, only recorded for one property. The data driven approach uses a single level Chi-square Automatic Interaction Detector (CHAID) to group the levels within each categorical variable into a smaller number of groups. CHAID groups values with a similar response rate or in this context Energy Efficiency Rating (EER).
#
# This script run CHAID and stores the results in a dictionary

# %%
import numpy as np
import pandas as pd
import datetime
import os
import glob
import json
from CHAID import Tree
import re

# %%
# set variables from config file
config_path = os.path.abspath('..')

with open(config_path + '/config-example.json', 'r') as f:
    config = json.load(f)

processing_path = config['DEFAULT']['processing_path']
epc_train_fname = config['DEFAULT']['epc_train_fname']
epc_test_fname = config['DEFAULT']['epc_test_fname']
epc_train_clean_fname = config['DEFAULT']['epc_train_clean_fname']
epc_chaid_fname = config['DEFAULT']['epc_chaid_fname']
epc_fname_suffix = config['DEFAULT']['epc_fname_suffix']

# %%
dtype_dict = {'INSPECTION_DATE':'str'}

epc_train = pd.read_csv(os.path.join(processing_path,epc_train_clean_fname + epc_fname_suffix),
                        header = 0,
                        delimiter = ',',
                        dtype = dtype_dict,
                        parse_dates = ['INSPECTION_DATE'])
# Out:
# C:\Users\KingRemy\AppData\Local\Temp\ipykernel_11968\425336681.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   epc_train = pd.read_csv(os.path.join(processing_path,epc_train_clean_fname + epc_fname_suffix),

# %%
#Get quantile boundafries
quantiles = epc_train['CURRENT_ENERGY_EFFICIENCY'].describe()
print(quantiles['25%'])
print(quantiles['75%'])
# Out:
# 56.0
# 73.0

# %%
#Create a new new target field within the training data
min_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].min()
max_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].max()
epc_train['eff_flag'] = pd.cut(epc_train['CURRENT_ENERGY_EFFICIENCY'],
                               bins = [min_eff,56.0,73.0,max_eff],
                               labels = ['0','99','1'])

#Drop unwated '99' level of eff_flag and convert to integer
epc_train = epc_train[epc_train['eff_flag'].isin(['0','1'])]
epc_train['eff_flag'] = epc_train['eff_flag'].astype(int)

# %%
#Get the {0,1} sample size by taking the smallest class from the 0
#and 1 outcomes
sample_size = epc_train['eff_flag'].value_counts().min()


#Subsample positive and negative samples
neg_eff_flag = epc_train[epc_train['eff_flag'] == 0].sample(sample_size,random_state = 1234,axis = 0)

pos_eff_flag = epc_train[epc_train['eff_flag'] == 1].sample(sample_size,random_state = 1234,axis = 0)

#Concatenate
epc_chaid = pd.concat([neg_eff_flag, pos_eff_flag])
epc_chaid['eff_flag'].value_counts()

#Randomly shuffle epc_CHAID and reset the index
epc_chaid = epc_chaid.sample(frac = 1).reset_index(drop=True)

# %%
epc_chaid
# Out:
#                                     LMK_KEY       region  POSTCODE  \
# 0         279776450742009050621084561110268     Bolsover  DE55 3DB
# 1         848408140612012102216145096229107   Chichester  PO18 8FF
# 2        1427717759602016032407221444362778      Ashford  TN24 8HB
# 3         472444875952010042013533990200570      Chorley   PR6 7TH
# 4          93419920842009100816080246610188     Basildon  SS16 4SL
# ...                                     ...          ...       ...
# 1912829   788030549962012051415494798548232     Wychavon  WR10 3EA
# 1912830   220084449212020030409275429000955  Scarborough  YO11 2SY
# 1912831   876927169102013082015473009479548        Lewes  BN25 2RS
# 1912832  1412010012612016021009474594960844   Harborough  LE16 7EH
# 1912833   338142008132009080409504157068401    Cambridge   CB4 1ZA
#
#          BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 0                       8703651668                     E
# 1                       1728062078                     B
# 2                       9698253478                     E
# 3                       5006505768                     B
# 4                       4801126468                     E
# ...                            ...                   ...
# 1912829                 3996438968                     B
# 1912830                 9586996568                     E
# 1912831                 5104364078                     E
# 1912832                 8422242478                     E
# 1912833                  147465668                     C
#
#          CURRENT_ENERGY_EFFICIENCY PROPERTY_TYPE     BUILT_FORM  \
# 0                               42         House    End-Terrace
# 1                               84         House       Detached
# 2                               53          Flat  Semi-Detached
# 3                               83          Flat       Detached
# 4                               54         House    Mid-Terrace
# ...                            ...           ...            ...
# 1912829                         83         House  Semi-Detached
# 1912830                         43          Flat  Semi-Detached
# 1912831                         52      Bungalow       Detached
# 1912832                         41         House  Semi-Detached
# 1912833                         80          Flat            NaN
#
#         INSPECTION_DATE           COUNTY  ... FLOOR_HEIGHT  \
# 0            2009-05-06       Derbyshire  ...         2.55
# 1            2012-10-22      West Sussex  ...          NaN
# 2            2016-03-23             Kent  ...         2.65
# 3            2010-04-20       Lancashire  ...         2.40
# 4            2009-10-08            Essex  ...         2.38
# ...                 ...              ...  ...          ...
# 1912829      2012-05-14   Worcestershire  ...         2.40
# 1912830      2020-03-04  North Yorkshire  ...          NaN
# 1912831      2013-08-14      East Sussex  ...          NaN
# 1912832      2016-02-10   Leicestershire  ...          NaN
# 1912833      2009-08-03   Cambridgeshire  ...         2.43
#
#          MECHANICAL_VENTILATION  inspection_year  \
# 0                       natural             2009
# 1                           NaN             2012
# 2                       natural             2016
# 3                       natural             2010
# 4                       natural             2009
# ...                         ...              ...
# 1912829                     NaN             2012
# 1912830                 natural             2020
# 1912831                 natural             2013
# 1912832                 natural             2016
# 1912833                 natural             2009
#
#          floors_average_thermal_transmittance  \
# 0                                         NaN
# 1                                         0.2
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1912829                                   0.2
# 1912830                                   NaN
# 1912831                                   NaN
# 1912832                                   NaN
# 1912833                                   NaN
#
#                       SECONDHEAT_DESCRIPTION  \
# 0                    Room heaters, mains gas
# 1                                       None
# 2                                       None
# 3                     Room heaters, electric
# 4                                       None
# ...                                      ...
# 1912829                                 None
# 1912830  Portable electric heaters (assumed)
# 1912831                                 None
# 1912832              Room heaters, mains gas
# 1912833                                 None
#
#                              LIGHTING_DESCRIPTION  low_energy_lighting_perc  \
# 0        low energy lighting 80% of fixed outlets                      80.0
# 1        low energy lighting in all fixed outlets                       NaN
# 2        low energy lighting 50% of fixed outlets                      50.0
# 3        low energy lighting 60% of fixed outlets                      60.0
# 4                          no low energy lighting                       NaN
# ...                                           ...                       ...
# 1912829  low energy lighting in all fixed outlets                       NaN
# 1912830  low energy lighting in all fixed outlets                       NaN
# 1912831  low energy lighting 10% of fixed outlets                      10.0
# 1912832                    no low energy lighting                       NaN
# 1912833  low energy lighting 40% of fixed outlets                      40.0
#
#          roof_average_thermal_transmittance  \
# 0                                       NaN
# 1                                       0.1
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1912829                                 0.1
# 1912830                                 NaN
# 1912831                                 NaN
# 1912832                                 NaN
# 1912833                                 NaN
#
#         walls_average_thermal_transmittance eff_flag
# 0                                       NaN        0
# 1                                       0.3        1
# 2                                       NaN        0
# 3                                       NaN        1
# 4                                       NaN        0
# ...                                     ...      ...
# 1912829                                 0.2        1
# 1912830                                 NaN        0
# 1912831                                 NaN        0
# 1912832                                 NaN        0
# 1912833                                 NaN        1
#
# [1912834 rows x 61 columns]

# %%
#Numeric
var_list_num = epc_chaid.select_dtypes(include= 'number').columns.tolist()
var_list_num.remove('CURRENT_ENERGY_EFFICIENCY')

#Categorical
var_list_cat = epc_chaid.select_dtypes(include= ['object','category']).columns.tolist()
var_list_cat.remove('LMK_KEY')
var_list_cat.remove('POSTCODE')
var_list_cat.remove('CURRENT_ENERGY_RATING')

# %% [markdown]
# ### Creating a dictionary of CHAID scores

# %%
chaid_dict = {}
for var in var_list_cat:
    #Set the inputs and outputs
    #The imputs are given as a dictionary along with the type
    #The output must be of string type
    #I have assume all features are nominal, we can change the features dictionary to include the ordinal type
    features = {var:'nominal'}
    label = 'eff_flag'
    #Create the Tree
    chaid_dict[var] = {}
    tree = Tree.from_pandas_df(epc_chaid, i_variables = features, d_variable = label, alpha_merge = 0.0)
    #Loop through all the nodes and enter into a dictionary
    print(f'\n\n\nVariable: {var}')
    print(f'p-value: {tree.tree_store[0].split.p}')
    print(f'Chi2: {tree.tree_store[0].split.score}')
    for i in range(1, len(tree.tree_store)):
        count = tree.tree_store[i].members[0] + tree.tree_store[i].members[1]
        rate = tree.tree_store[i].members[1] / count
        print(f'\nNode {i}:\n\tCount = {count}\tRate = {rate}')
        print(f'\t{tree.tree_store[i].choices}')
        chaid_dict[var]['node' + str(i)] = tree.tree_store[i].choices
# Out:
# Variable: region
# p-value: 0.0
# Chi2: 65517.82722484344
#
# Node 1:
# 	Count = 433464.0	Rate = 0.45513352896665005
# 	['Adur', 'Gedling', 'Bassetlaw', 'Cotswold', 'Teignbridge', 'Boston', 'Thanet', 'Hastings', 'Ashfield', 'Babergh', 'Lewes', 'Waverley', 'Breckland', 'Guildford', 'Worcester', 'Fylde', 'Wealden', 'Bolsover', 'Brentwood', 'Carlisle', 'Broadland', 'Rochford', 'Dover', 'Stroud', 'Chichester']
#
# Node 2:
# 	Count = 301953.0	Rate = 0.37460796878984476
# 	['Allerdale', 'Rossendale', 'Craven', 'Broxtowe', 'Ryedale', 'Torridge', 'Copeland', 'Richmondshire', 'Erewash', 'Tendring', 'Worthing', 'Rother', 'Scarborough', 'Hambleton', 'Harrogate', 'Lancaster', 'Wyre', 'Melton', 'Sevenoaks', 'Maldon']
#
# Node 3:
# 	Count = 364964.0	Rate = 0.5059348319286285
# 	['Arun', 'Blaby', 'Sedgemoor', 'Braintree', 'Swale', 'Havant', 'Stafford', 'Canterbury', 'Cheltenham', 'Preston', 'Bromsgrove', 'Spelthorne', 'Chesterfield', 'Fenland', 'Mansfield', 'Elmbridge', 'Mendip', 'Rushcliffe', 'Tandridge', 'Gravesham']
#
# Node 4:
# 	Count = 318629.0	Rate = 0.6350520511315668
# 	['Ashford', 'Cherwell', 'Watford', 'Rugby', 'Colchester', 'Exeter', 'Maidstone', 'Stevenage', 'Harlow', 'Tewkesbury', 'Rushmoor', 'Norwich', 'Cambridge', 'Hart', 'Crawley', 'Dartford', 'Eastleigh']
#
# Node 5:
# 	Count = 438433.0	Rate = 0.5589748034477332
# 	['Basildon', 'Woking', 'Huntingdonshire', 'Uttlesford', 'Chorley', 'Chelmsford', 'Hertsmere', 'Fareham', 'Gosport', 'Gloucester', 'Harborough', 'Broxbourne', 'Redditch', 'Selby', 'Runnymede', 'Charnwood', 'Warwick', 'Eastbourne', 'Lichfield', 'Lincoln', 'Dacorum', 'Horsham', 'Wychavon', 'Oxford', 'Tamworth']
#
# Node 6:
# 	Count = 55391.0	Rate = 0.251882074705277
# 	['Burnley', 'Hyndburn', 'Eden', 'Pendle']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\KingRemy\OneDrive - University of Keele\Documents\SEND\Energy-Efficiency-and-Heat-Loss-Tool\02_Preprocessing\05_CHAID.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/SEND/Energy-Efficiency-and-Heat-Loss-Tool/02_Preprocessing/05_CHAID.ipynb#X13sZmlsZQ%3D%3D?line=8'>9</a> #Create the Tree
#      <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/SEND/Energy-Efficiency-and-Heat-Loss-Tool/02_Preprocessing/05_CHAID.ipynb#X13sZmlsZQ%3D%3D?line=9'>10</a> chaid_dict[var] = {}
# ---> <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/SEND/Energy-Efficiency-and-Heat-Loss-Tool/02_Preprocessing/05_CHAID.ipynb#X13sZmlsZQ%3D%3D?line=10'>11</a> tree = Tree.from_pandas_df(epc_chaid, i_variables = features, d_variable = label, alpha_merge = 0.0)
#      <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/SEND/Energy-Efficiency-and-Heat-Loss-Tool/02_Preprocessing/05_CHAID.ipynb#X13sZmlsZQ%3D%3D?line=11'>12</a> #Loop through all the nodes and enter into a dictionary
#      <a href='vscode-notebook-cell:/c%3A/Users/KingRemy/OneDrive%20-%20University%20of%20Keele/Documents/SEND/Energy-Efficiency-and-Heat-Loss-Tool/02_Preprocessing/05_CHAID.ipynb#X13sZmlsZQ%3D%3D?line=12'>13</a> print(f'\n\n\nVariable: {var}')
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\CHAID\tree.py:151, in Tree.from_pandas_df(df, i_variables, d_variable, alpha_merge, max_depth, min_parent_node_size, min_child_node_size, split_threshold, weight, dep_variable_type)
#     149 dep_values = df[d_variable].values
#     150 weights = df[weight] if weight is not None else None
# --> 151 return Tree.from_numpy(ind_values, dep_values, alpha_merge, max_depth, min_parent_node_size,
#     152             min_child_node_size, list(ind_df.columns.values), split_threshold, weights,
#     153             list(i_variables.values()), dep_variable_type)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\CHAID\tree.py:83, in Tree.from_numpy(ndarr, arr, alpha_merge, max_depth, min_parent_node_size, min_child_node_size, split_titles, split_threshold, weights, variable_types, dep_variable_type)
#      81     col = OrdinalColumn(ndarr[:, ind], name=title)
#      82 elif col_type == 'nominal':
# ---> 83     col = NominalColumn(ndarr[:, ind], name=title)
#      84 else:
#      85     raise NotImplementedError('Unknown independent variable type ' + col_type)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\CHAID\column.py:91, in NominalColumn.__init__(self, arr, metadata, missing_id, substitute, weights, name)
#      89 super(self.__class__, self).__init__(arr, metadata=metadata, missing_id=missing_id, weights=weights, name=name)
#      90 if substitute and metadata is None:
# ---> 91     self.substitute_values(arr)
#      93 self._groupings = MappingDict()
#      94 for x in np.unique(self.arr):
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\CHAID\column.py:129, in NominalColumn.substitute_values(self, vect)
#     127 arr = np.copy(vect)
#     128 for new_id, value in enumerate(unique):
# --> 129     np.place(arr, arr==value, new_id)
#     130     self.metadata[new_id] = value
#     131 arr = arr.astype(np.float)
#
# File <__array_function__ internals>:179, in place(*args, **kwargs)
#
# File c:\Users\KingRemy\anaconda3\envs\elec\lib\site-packages\numpy\lib\function_base.py:1908, in _place_dispatcher(arr, mask, vals)
#    1858     """
#    1859     Return the elements of an array that satisfy some condition.
#    1860
#    (...)
#    1903
#    1904     """
#    1905     return _nx.take(ravel(arr), nonzero(ravel(condition))[0])
# -> 1908 def _place_dispatcher(arr, mask, vals):
#    1909     return (arr, mask, vals)
#    1912 @array_function_dispatch(_place_dispatcher)
#    1913 def place(arr, mask, vals):
#
# KeyboardInterrupt:

# %%
# %store chaid_dict
# Out:
# Stored 'chaid_dict' (dict)
