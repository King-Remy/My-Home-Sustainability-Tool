# %% [markdown]
# # CHAID
#
# The EPC data contains several categorical variables with a lot of values. In order to find suitable features which will retain the most information, three feature sets are explored;
# * data driven
# * domain driven
# * exhaustive
#
# The first approach, termed data driven, uses statistical methods to reduce the number of variables. As the variables containing textual descriptions of the property have been created free-hand, many contain a large number of unique values. In some cases, only recorded for one property. The data driven approach uses a single level Chi-square Automatic Interaction Detector (CHAID) to group the levels within each categorical variable into a smaller number of groups. CHAID groups values with a similar response rate or in this context Energy Efficiency Rating (EER).
#
# This script run CHAID and stores the results in a dictionary

# %%
import numpy as np
import pandas as pd
import datetime
import os
import glob
import json
from CHAID import Tree
import re

# %%
# set variables from config file
config_path = os.path.abspath('..')

with open(config_path + '/config-example.json', 'r') as f:
    config = json.load(f)

processing_path = config['DEFAULT']['processing_path']
epc_train_fname = config['DEFAULT']['epc_train_fname']
epc_test_fname = config['DEFAULT']['epc_test_fname']
epc_train_clean_fname = config['DEFAULT']['epc_train_clean_fname']
epc_chaid_fname = config['DEFAULT']['epc_chaid_fname']
epc_fname_suffix = config['DEFAULT']['epc_fname_suffix']

# %%
dtype_dict = {'INSPECTION_DATE':'str'}

epc_train = pd.read_csv(os.path.join(processing_path,epc_train_clean_fname + epc_fname_suffix),
                        header = 0,
                        delimiter = ',',
                        dtype = dtype_dict,
                        parse_dates = ['INSPECTION_DATE'])
# Out:
# C:\Users\KingRemy\AppData\Local\Temp\ipykernel_15132\425336681.py:3: DtypeWarning: Columns (21) have mixed types. Specify dtype option on import or set low_memory=False.
#   epc_train = pd.read_csv(os.path.join(processing_path,epc_train_clean_fname + epc_fname_suffix),

# %%
#Get quantile boundafries
quantiles = epc_train['CURRENT_ENERGY_EFFICIENCY'].describe()
print(quantiles['25%'])
print(quantiles['75%'])
# Out:
# 56.0
# 73.0

# %%
#Create a new new target field within the training data
min_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].min()
max_eff = epc_train['CURRENT_ENERGY_EFFICIENCY'].max()
epc_train['eff_flag'] = pd.cut(epc_train['CURRENT_ENERGY_EFFICIENCY'],
                               bins = [min_eff,56.0,73.0,max_eff],
                               labels = ['0','99','1'])

#Drop unwated '99' level of eff_flag and convert to integer
epc_train = epc_train[epc_train['eff_flag'].isin(['0','1'])]
epc_train['eff_flag'] = epc_train['eff_flag'].astype(int)

# %%
#Get the {0,1} sample size by taking the smallest class from the 0
#and 1 outcomes
sample_size = epc_train['eff_flag'].value_counts().min()


#Subsample positive and negative samples
neg_eff_flag = epc_train[epc_train['eff_flag'] == 0].sample(sample_size,random_state = 1234,axis = 0)

pos_eff_flag = epc_train[epc_train['eff_flag'] == 1].sample(sample_size,random_state = 1234,axis = 0)

#Concatenate
epc_chaid = pd.concat([neg_eff_flag, pos_eff_flag])
epc_chaid['eff_flag'].value_counts()

#Randomly shuffle epc_CHAID and reset the index
epc_chaid = epc_chaid.sample(frac = 1).reset_index(drop=True)

# %%
epc_chaid
# Out:
#                                                    LMK_KEY     region  \
# 0                        993440771432014092515085604278505     Thanet
# 1                        506194479962017041122155827098213      Dover
# 2                        172478398912016061417050693960352   Hyndburn
# 3        cda70534b1823b7871ebed55dace911f28edfd3fca6218...   Cherwell
# 4                        907117857732013040316124637278507   Worthing
# ...                                                    ...        ...
# 1912829                 1309878129742015042215345132552128    Ashford
# 1912830                 1481276359222016092216073507798726    Gedling
# 1912831                 1567938489922017081812071143068243     Exeter
# 1912832                 1661984051832018091017185523978104       Arun
# 1912833  0fbeabaafb3ebcf2bd5c82673336b3cd2e0ae17079cd18...  Harrogate
#
#          POSTCODE  BUILDING_REFERENCE_NUMBER CURRENT_ENERGY_RATING  \
# 0        CT12 6QX                 7514582178                     E
# 1        CT13 0PG                 1273747768                     F
# 2         BB5 4AT                 3225833568                     D
# 3        OX27 9AX                10000302845                     E
# 4        BN13 1HW                 5767576078                     F
# ...           ...                        ...                   ...
# 1912829  TN26 2HS                 5708225378                     E
# 1912830   NG4 2FH                 2052537478                     F
# 1912831   EX4 8QW                 4483843578                     F
# 1912832  PO22 7AR                 5423120678                     E
# 1912833   HG5 0TW                10002561074                     B
#
#          CURRENT_ENERGY_EFFICIENCY PROPERTY_TYPE     BUILT_FORM  \
# 0                               45         House    Mid-Terrace
# 1                               27         House  Semi-Detached
# 2                               55         House  Semi-Detached
# 3                               50         House  Semi-Detached
# 4                               34         House    Mid-Terrace
# ...                            ...           ...            ...
# 1912829                         49         House  Semi-Detached
# 1912830                         38         House  Semi-Detached
# 1912831                         37         House    Mid-Terrace
# 1912832                         53    Maisonette       Detached
# 1912833                         86         House       Detached
#
#         INSPECTION_DATE           COUNTY  ... FLOOR_HEIGHT  \
# 0            2014-09-24             Kent  ...          NaN
# 1            2017-04-11             Kent  ...         2.45
# 2            2016-06-14       Lancashire  ...         2.80
# 3            2021-03-17      Oxfordshire  ...         2.87
# 4            2013-03-22      West Sussex  ...          NaN
# ...                 ...              ...  ...          ...
# 1912829      2015-04-22             Kent  ...          NaN
# 1912830      2016-09-21  Nottinghamshire  ...         2.59
# 1912831      2017-08-16            Devon  ...          NaN
# 1912832      2018-09-10      West Sussex  ...          NaN
# 1912833      2022-04-19  North Yorkshire  ...         2.40
#
#          MECHANICAL_VENTILATION  inspection_year  \
# 0                       natural             2014
# 1                       natural             2017
# 2                       natural             2016
# 3                       natural             2021
# 4                       natural             2013
# ...                         ...              ...
# 1912829                 natural             2015
# 1912830                 natural             2016
# 1912831                 natural             2017
# 1912832                 natural             2018
# 1912833                     NaN             2022
#
#          floors_average_thermal_transmittance  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 1912829                                   NaN
# 1912830                                   NaN
# 1912831                                   NaN
# 1912832                                   NaN
# 1912833                                   0.1
#
#                       SECONDHEAT_DESCRIPTION  \
# 0                    Room heaters, mains gas
# 1                                       None
# 2                    Room heaters, mains gas
# 3                                       None
# 4                     Room heaters, electric
# ...                                      ...
# 1912829                                 None
# 1912830              Room heaters, mains gas
# 1912831               Room heaters, electric
# 1912832  Portable electric heaters (assumed)
# 1912833                                 None
#
#                              LIGHTING_DESCRIPTION  low_energy_lighting_perc  \
# 0        low energy lighting 80% of fixed outlets                      80.0
# 1        low energy lighting 60% of fixed outlets                      60.0
# 2                          no low energy lighting                       NaN
# 3        low energy lighting 60% of fixed outlets                      60.0
# 4        low energy lighting 50% of fixed outlets                      50.0
# ...                                           ...                       ...
# 1912829  low energy lighting 20% of fixed outlets                      20.0
# 1912830  low energy lighting 40% of fixed outlets                      40.0
# 1912831  low energy lighting 10% of fixed outlets                      10.0
# 1912832                    no low energy lighting                       NaN
# 1912833  low energy lighting in all fixed outlets                       NaN
#
#          roof_average_thermal_transmittance  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 1912829                                 NaN
# 1912830                                 NaN
# 1912831                                 NaN
# 1912832                                 NaN
# 1912833                                 0.1
#
#         walls_average_thermal_transmittance eff_flag
# 0                                       NaN        0
# 1                                       NaN        0
# 2                                       NaN        0
# 3                                       NaN        0
# 4                                       NaN        0
# ...                                     ...      ...
# 1912829                                 NaN        0
# 1912830                                 NaN        0
# 1912831                                 NaN        0
# 1912832                                 NaN        0
# 1912833                                 0.2        1
#
# [1912834 rows x 61 columns]

# %%
#Numeric
var_list_num = epc_chaid.select_dtypes(include= 'number').columns.tolist()
var_list_num.remove('CURRENT_ENERGY_EFFICIENCY')

#Categorical
var_list_cat = epc_chaid.select_dtypes(include= ['object','category']).columns.tolist()
var_list_cat.remove('LMK_KEY')
var_list_cat.remove('POSTCODE')
var_list_cat.remove('CURRENT_ENERGY_RATING')

# %% [markdown]
# ### Creating a dictionary of CHAID scores

# %%
chaid_dict = {}
for var in var_list_cat:
    #Set the inputs and outputs
    #The imputs are given as a dictionary along with the type
    #The output must be of string type
    #I have assume all features are nominal, we can change the features dictionary to include the ordinal type
    features = {var:'nominal'}
    label = 'eff_flag'
    #Create the Tree
    chaid_dict[var] = {}
    tree = Tree.from_pandas_df(epc_chaid, i_variables = features, d_variable = label, alpha_merge = 0.0)
    #Loop through all the nodes and enter into a dictionary
    print(f'\n\n\nVariable: {var}')
    print(f'p-value: {tree.tree_store[0].split.p}')
    print(f'Chi2: {tree.tree_store[0].split.score}')
    for i in range(1, len(tree.tree_store)):
        count = tree.tree_store[i].members[0] + tree.tree_store[i].members[1]
        rate = tree.tree_store[i].members[1] / count
        print(f'\nNode {i}:\n\tCount = {count}\tRate = {rate}')
        print(f'\t{tree.tree_store[i].choices}')
        chaid_dict[var]['node' + str(i)] = tree.tree_store[i].choices
# Out:
# Variable: region
# p-value: 0.0
# Chi2: 65517.82722484344
#
# Node 1:
# 	Count = 433464.0	Rate = 0.45513352896665005
# 	['Adur', 'Gedling', 'Bassetlaw', 'Cotswold', 'Teignbridge', 'Boston', 'Thanet', 'Hastings', 'Ashfield', 'Babergh', 'Lewes', 'Waverley', 'Breckland', 'Guildford', 'Worcester', 'Fylde', 'Wealden', 'Bolsover', 'Brentwood', 'Carlisle', 'Broadland', 'Rochford', 'Dover', 'Stroud', 'Chichester']
#
# Node 2:
# 	Count = 301953.0	Rate = 0.37460796878984476
# 	['Allerdale', 'Rossendale', 'Craven', 'Broxtowe', 'Ryedale', 'Torridge', 'Copeland', 'Richmondshire', 'Erewash', 'Tendring', 'Worthing', 'Rother', 'Scarborough', 'Hambleton', 'Harrogate', 'Lancaster', 'Wyre', 'Melton', 'Sevenoaks', 'Maldon']
#
# Node 3:
# 	Count = 364964.0	Rate = 0.5059348319286285
# 	['Arun', 'Blaby', 'Sedgemoor', 'Braintree', 'Swale', 'Havant', 'Stafford', 'Canterbury', 'Cheltenham', 'Preston', 'Bromsgrove', 'Spelthorne', 'Chesterfield', 'Fenland', 'Mansfield', 'Elmbridge', 'Mendip', 'Rushcliffe', 'Tandridge', 'Gravesham']
#
# Node 4:
# 	Count = 318629.0	Rate = 0.6350520511315668
# 	['Ashford', 'Cherwell', 'Watford', 'Rugby', 'Colchester', 'Exeter', 'Maidstone', 'Stevenage', 'Harlow', 'Tewkesbury', 'Rushmoor', 'Norwich', 'Cambridge', 'Hart', 'Crawley', 'Dartford', 'Eastleigh']
#
# Node 5:
# 	Count = 438433.0	Rate = 0.5589748034477332
# 	['Basildon', 'Woking', 'Huntingdonshire', 'Uttlesford', 'Chorley', 'Chelmsford', 'Hertsmere', 'Fareham', 'Gosport', 'Gloucester', 'Harborough', 'Broxbourne', 'Redditch', 'Selby', 'Runnymede', 'Charnwood', 'Warwick', 'Eastbourne', 'Lichfield', 'Lincoln', 'Dacorum', 'Horsham', 'Wychavon', 'Oxford', 'Tamworth']
#
# Node 6:
# 	Count = 55391.0	Rate = 0.251882074705277
# 	['Burnley', 'Hyndburn', 'Eden', 'Pendle']
#
#
#
# Variable: PROPERTY_TYPE
# p-value: 0.0
# Chi2: 218700.9676578921
#
# Node 1:
# 	Count = 175429.0	Rate = 0.19924869890383004
# 	['Bungalow', 'Park home']
#
# Node 2:
# 	Count = 517277.0	Rate = 0.7551137978297895
# 	['Flat']
#
# Node 3:
# 	Count = 1220128.0	Rate = 0.4350854992263107
# 	['House', 'Maisonette']
#
#
#
# Variable: BUILT_FORM
# p-value: 0.0
# Chi2: 74408.08267605692
#
# Node 1:
# 	Count = 81088.0	Rate = 0.8855687647987371
# 	['<missing>', 'Enclosed Mid-Terrace']
#
# Node 2:
# 	Count = 671840.0	Rate = 0.5456358656823053
# 	['End-Terrace', 'Mid-Terrace']
#
# Node 3:
# 	Count = 539547.0	Rate = 0.41933510889690795
# 	['Semi-Detached']
#
# Node 4:
# 	Count = 29889.0	Rate = 0.6567633577570343
# 	['Enclosed End-Terrace']
#
# Node 5:
# 	Count = 590470.0	Rate = 0.4608989449082934
# 	['Detached']
#
#
#
# Variable: COUNTY
# p-value: 0.0
# Chi2: 28414.48117652582
#
# Node 1:
# 	Count = 318515.0	Rate = 0.5895201167919878
# 	['<missing>', 'Hampshire', 'Warwickshire', 'Hertfordshire', 'Cambridgeshire', 'Oxfordshire']
#
# Node 2:
# 	Count = 1037337.0	Rate = 0.5170875038680776
# 	['Worcestershire', 'Norfolk', 'Gloucestershire', 'Leicestershire', 'Kent', 'Essex', 'Staffordshire', 'Somerset', 'Surrey', 'Lincolnshire', 'West Sussex', 'Devon']
#
# Node 3:
# 	Count = 250574.0	Rate = 0.4469697574369248
# 	['East Sussex', 'Suffolk', 'Nottinghamshire', 'Derbyshire']
#
# Node 4:
# 	Count = 306408.0	Rate = 0.3924603796245529
# 	['North Yorkshire', 'Lancashire', 'Cumbria']
#
#
#
# Variable: TRANSACTION_TYPE
# p-value: 0.0
# Chi2: 752867.6014206854
#
# Node 1:
# 	Count = 272109.0	Rate = 0.3793259318875892
# 	['<missing>', 'not sale or rental', 'not recorded', 'RHI application', 'rental (private)', 'following green deal']
#
# Node 2:
# 	Count = 763273.0	Rate = 0.27758613235369256
# 	['non marketed sale', 'marketed sale']
#
# Node 3:
# 	Count = 150022.0	Rate = 0.7839916812200877
# 	['Stock condition survey', 'rental (social)']
#
# Node 4:
# 	Count = 104770.0	Rate = 0.6527822850052496
# 	['rental', 'Stock Condition Survey', 'FiT application']
#
# Node 5:
# 	Count = 78383.0	Rate = 0.17192503476519144
# 	['none of the above']
#
# Node 6:
# 	Count = 105281.0	Rate = 0.07633856061397593
# 	['assessment for green deal', 'ECO assessment']
#
# Node 7:
# 	Count = 438996.0	Rate = 0.9881730129659496
# 	['new dwelling']
#
#
#
# Variable: ENERGY_TARIFF
# p-value: 0.0
# Chi2: 557530.6204282687
#
# Node 1:
# 	Count = 164234.0	Rate = 0.4347638126088386
# 	['<missing>', 'off-peak 18 hour']
#
# Node 2:
# 	Count = 51278.0	Rate = 0.6469831116658216
# 	['off-peak 7 hour', 'off-peak 10 hour']
#
# Node 3:
# 	Count = 945082.0	Rate = 0.3488670824330587
# 	['Single', 'dual (24 hour)']
#
# Node 4:
# 	Count = 452564.0	Rate = 0.9718669624627677
# 	['standard tariff', '24 hour', '5']
#
# Node 5:
# 	Count = 299676.0	Rate = 0.2746232597872369
# 	['dual']
#
#
#
# Variable: MAINS_GAS_FLAG
# p-value: 0.0
# Chi2: 578658.4707380498
#
# Node 1:
# 	Count = 450678.0	Rate = 0.9820603623873364
# 	['<missing>']
#
# Node 2:
# 	Count = 1053506.0	Rate = 0.39647804568744743
# 	['Y']
#
# Node 3:
# 	Count = 408650.0	Rate = 0.23524287287409765
# 	['N']
#
#
#
# Variable: FLOOR_LEVEL
# p-value: 0.0
# Chi2: 211452.3086456073
#
# Node 1:
# 	Count = 1359135.0	Rate = 0.4025913540597512
# 	['<missing>', '-1', '15th', '0', '15', '14.0', '11.0', '20+', '-1.0', '18.0', '18th', '16th', '17th', 'Basement']
#
# Node 2:
# 	Count = 71844.0	Rate = 0.7717554701854017
# 	['0.0', '6th', '9.0', '13th', '9th', '13', '4.0', '02', '01', '04', '8.0', '6.0', '7.0', '03', '1.0', '5.0', '10', '19', '08', '11', '06', '05', '07', '12.0', '2.0', '3.0']
#
# Node 3:
# 	Count = 116600.0	Rate = 0.9654545454545455
# 	['2', '20', '12', '16', '17', '19.0', '16.0', 'mid floor', 'ground floor', '1', '3', 'top floor']
#
# Node 4:
# 	Count = 365255.0	Rate = 0.6604235397188266
# 	['2nd', '3rd', '8th', '09', '00', '5th', '15.0', '14', '13.0', '1st', '11th', '12th', '4th', '7th', '18', '21st or above', '10th', '14th', 'Ground', '10.0']
#
#
#
# Variable: MAIN_HEATING_CONTROLS
# p-value: 0.0
# Chi2: 153677.75721213943
#
# Node 1:
# 	Count = 1647159.0	Rate = 0.5505716205903619
# 	['<missing>', '2705', '2109', '2106.0', '2106', '2205.0', '2110.0', '2506.0', '2706.0', '2706', '2208.0', '2302.0', '2307', '2506', '2205', '2110', '2301', '2207.0']
#
# Node 2:
# 	Count = 142548.0	Rate = 0.13244661447372114
# 	['2604.0', '2201.0', '2602', '2103', '2104.0', '2604', '2701.0', '2103.0', '2107', '2104', '2107.0', '2605', '2602.0', '2111.0', '2111', '2503.0', '2504', '2502.0', '2504.0']
#
# Node 3:
# 	Count = 65874.0	Rate = 0.3149497525579136
# 	['2404', '2402.0', '2705.0', '2109.0', '2402', '2404.0', '2203.0', '2204.0', '2206', '17.0', '2302', '2203', '2105', '2105.0', '2704', '2206.0', '2704.0', '2204', '2401', '2605.0', '2401.0', '2505.0', '2603.0', '2703', '2703.0', '2503', '2202.0', '2502', '2603', '2702.0']
#
# Node 4:
# 	Count = 10104.0	Rate = 0.9051860649247823
# 	['2301.0', '2403.0', '2108.0', '2312.0', '2207', '2304.0', '2304', '2307.0', '2309', '2309.0', '2305.0', '2306.0', '2310.0', '2305', '2303', '2311.0', '2303.0', '2308.0', '2112.0', '1.0', '2310', '2202', '2208', '2306', '2311', '2312']
#
# Node 5:
# 	Count = 47149.0	Rate = 0.016225158539947826
# 	['2701', '4.0', '2100', '0.0', '2308', '2501', '2702', '2201', '2505', '2699.0', '2102.0', '2102', '%%mainheatcontrol%%', '2101', '2100.0', '2699', '2101.0', '2501.0', '2601.0', '2601']
#
#
#
# Variable: GLAZED_TYPE
# p-value: 0.0
# Chi2: 521908.64147276524
#
# Node 1:
# 	Count = 567564.0	Rate = 0.8172399940799628
# 	['<missing>', 'double, known data', 'triple, known data']
#
# Node 2:
# 	Count = 828355.0	Rate = 0.23243174725812002
# 	['double glazing, unknown install date', 'double glazing installed before 2002']
#
# Node 3:
# 	Count = 39900.0	Rate = 0.08283208020050126
# 	['secondary glazing', 'single glazing']
#
# Node 4:
# 	Count = 477015.0	Rate = 0.6220768738928545
# 	['double glazing installed during or after 2002', 'triple glazing']
#
#
#
# Variable: HOTWATER_DESCRIPTION
# p-value: 0.0
# Chi2: 347075.431740206
#
# Node 1:
# 	Count = 73867.0	Rate = 0.9653160409925948
# 	['<missing>', 'Community scheme, waste water heat recovery', 'Community scheme, plus solar', 'From main system |From main system', 'Electric immersion, off-peak, waste water heat recovery', 'Gas boiler/circulator for water heating only, plus solar', 'Heat pump, plus solar', 'Electric instantaneous at point of use, flue gas heat recovery', 'From main system, flue gas heat recovery, plus solar', 'Gas instantaneous at point of use, flue gas heat recovery', 'From main system, no cylinderstat, waste water heat recovery', 'Electric instantaneous at point of use, waste water heat recovery', 'From main system, flue gas heat recovery, no cylinderstat', 'From main system, plus solar, waste water heat recovery', 'Electric immersion, standard tariff, flue gas heat recovery, plus solar', 'Electric heat pump, plus solar', 'Community scheme, no cylinderstat, plus solar', 'From hot-water only Community scheme - heat pump, plus solar', 'From hot-water only Community scheme - boilers, waste water heat recovery', 'Community scheme, flue gas heat recovery', 'Electric heat pump for water heating only, flue gas heat recovery', 'From main system, no cylinderstat, flue gas heat recovery, plus solar', 'From main system, waste water heat recovery, no cylinderstat', 'No system present: electric immersion assumed, waste water heat recovery', 'From community heat pump', 'From main system, flue gas heat recovery, waste water heat recovery', 'Gas boiler/circulator, flue gas heat recovery', 'From secondary system, flue gas heat recovery', 'From main system, waste water heat recovery, flue gas heat recovery', 'Community scheme with CHP', 'From main system, waste water heat recovery', 'From main system, flue gas heat recovery', 'Community scheme', 'Heat pump']
#
# Node 2:
# 	Count = 106253.0	Rate = 0.18758058595992583
# 	['Electric immersion, standard tariff |underfloor heating, standard tariff', 'Gas range cooker, plus solar', 'Electric immersion, standard tariff', 'Gas multipoint, plus solar', 'Single-point gas water heater', 'From secondary system', 'Oil range cooker, plus solar', 'From main system, 7-hour tariff (on-peak)', 'Gas instantaneous at point of use', 'Electric immersion, off-peak |underfloor heating, off-peak', 'Electric heat pump for water heating only, no cylinderstat', 'From main system, no cylinderstat, plus solar', 'Electric instantaneous at point of use', 'Electric immersion, off-peak, no cylinderstat', 'Gas boiler/circulator', 'From main system, standard tariff']
#
# Node 3:
# 	Count = 198901.0	Rate = 0.03483642616175887
# 	['Gas boiler/circulator, no cylinderstat', 'No system present: electric immersion assumed', 'Solid fuel range cooker', 'Oil range cooker', 'Gas multipoint, no cylinderstat', 'Solid fuel boiler/circulator |Bwyler/cylchredydd tanwydd solet', 'Gas instantaneous at point of use, no cylinderstat', 'Gas range cooker, no cylinderstat, plus solar', 'Electric heat pump for water heating only, no cylinderstat, plus solar', 'underfloor heating, standard tariff', 'Electric instantaneous at point of use, no cylinderstat', ', no cylinderstat', 'From main system, no cylinderstat, flue gas heat recovery', 'Gas range cooker, no cylinderstat', 'underfloor heating, off-peak', 'Electric immersion, standard tariff, flue gas heat recovery, waste water heat recovery', 'Gas boiler/circulator, no cylinderstat, plus solar', 'Oil boiler/circulator, no cylinderstat, plus solar', 'Oil range cooker, no cylinderstat, plus solar', 'No system present: electric immersion assumed, no cylinderstat', ', no cylinderstat, plus solar', 'Solid fuel range cooker, no cylinderstat, plus solar', 'From main heating system', 'Gas range cooker', 'Solid fuel range cooker, no cylinderstat', 'Oil range cooker, no cylinderstat', 'Solid fuel boiler/circulator, no cylinderstat', 'From secondary system, no cylinderstat', 'Gas multipoint', 'Oil boiler/circulator', 'Electric multipoint', 'Solid fuel boiler/circulator', 'Oil boiler/circulator, no cylinderstat', 'Single-point gas water heater, standard tariff', 'From main system, no cylinderstat', 'Electric immersion, standard tariff, no cylinderstat']
#
# Node 4:
# 	Count = 202330.0	Rate = 0.34256907033064793
# 	['Solid fuel boiler/circulator, no cylinderstat, plus solar', 'Electric instantaneous at point of use, standard tariff', 'Oil boiler/circulator, plus solar', 'Electric immersion, dual tariff', 'Electric immersion, off-peak, plus solar', 'From secondary system, plus solar', 'Electric heat pump for water heating only', 'Electric instantaneous at point of use, plus solar', 'Single-point gas water heater, off-peak', 'Solid fuel range cooker, plus solar', 'Electric immersion, off-peak']
#
# Node 5:
# 	Count = 1312727.0	Rate = 0.5893296930740359
# 	['Electric heat pump', 'No system present: electric immersion assumed, plus solar', 'From main system', 'Electric immersion, standard tariff, plus solar']
#
# Node 6:
# 	Count = 18756.0	Rate = 0.8163254425250587
# 	['Solid fuel boiler/circulator, plus solar', 'Electric heat pump for water heating only, plus solar', 'From main system, plus solar', 'Electric immersion, off-peak, no cylinderstat, plus solar', 'Electric immersion, standard tariff, waste water heat recovery', 'Gas boiler/circulator, plus solar', 'Community scheme, no cylinderstat']
#
#
#
# Variable: HOT_WATER_ENERGY_EFF
# p-value: 0.0
# Chi2: 559403.9856041421
#
# Node 1:
# 	Count = 166388.0	Rate = 0.8869569920907758
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 420135.0	Rate = 0.12594761207707048
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 329051.0	Rate = 0.2330641754621624
# 	['Average']
#
# Node 4:
# 	Count = 997260.0	Rate = 0.6810992118404429
# 	['Good']
#
#
#
# Variable: HOT_WATER_ENV_EFF
# p-value: 0.0
# Chi2: 520311.1571491453
#
# Node 1:
# 	Count = 181569.0	Rate = 0.8877451547345637
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 460705.0	Rate = 0.2073452643231569
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 223515.0	Rate = 0.08015569424870814
# 	['Average']
#
# Node 4:
# 	Count = 1047045.0	Rate = 0.6511553944672865
# 	['Good']
#
#
#
# Variable: FLOOR_DESCRIPTION
# p-value: 0.0
# Chi2: 1071883.4756194234
#
# Node 1:
# 	Count = 378851.0	Rate = 0.9931582601075357
# 	['<missing>', 'average thermal transmittance 0.0 w/m²k', 'average thermal transmittance 0.2 w/m²k', 'average thermal transmittance 2.6 w/m²k', '(anheddiad arall islaw)', 'solet, wedii inswleiddio (rhagdybiaeth)', 'average thermal transmittance 2.0 w/m²k', 'solid', 'average thermal transmittance 0.1 w/m²k']
#
# Node 2:
# 	Count = 401022.0	Rate = 0.06786161357730998
# 	['conservatory', 'to unheated space, no insulation', 'average thermal transmittance 3.4 w/m²k', 'solet, dim inswleiddio (rhagdybiaeth)', 'to unheated space, limited insulation insulated', '(eiddo arall islaw)', 'average thermal transmittance 2.3 w/m²k', 'average thermal transmittance 1.7 w/m²k', 'average thermal transmittance 3.5 w/m²k', 'average thermal transmittance 2.1 w/m²k', 'average thermal transmittance 2.2 w/m²k', 'average thermal transmittance 2.7 w/m²k', 'average thermal transmittance 3.0 w/m²k', 'suspended, no insulation', 'to external air, no insulation']
#
# Node 3:
# 	Count = 420820.0	Rate = 0.7424219381208117
# 	['average thermal transmittance 1.5 w/m²k', '(same dwelling below) insulated', 'average thermal transmittance 0.8 w/m²k', 'average thermal transmittance 0.7 w/m²k', 'to unheated space, limited insulation', 'average thermal transmittance 1.0 w/m²k', 'to unheated space', 'average thermal transmittance 1.4 w/m²k', 'average thermal transmittance 0.9 w/m²k', 'average thermal transmittance 1.1 w/m²k', 'average thermal transmittance 0.5 w/m²k', 'to external air, limited insulation', 'suspended, limited insulation', 'average thermal transmittance 1.3 w/m²k', 'average thermal transmittance 0.6 w/m²k', 'solid, limited insulation', 'average thermal transmittance 0.4 w/m²k', 'other premises below', 'average thermal transmittance 0.3 w/m²k', 'to unheated space, insulated', 'to external air, insulated']
#
# Node 4:
# 	Count = 578608.0	Rate = 0.2012761662472693
# 	['crog, dim inswleiddio (rhagdybiaeth)', 'solid, no insulation', 'no insulation', 'average thermal transmittance 1.2 w/m²k']
#
# Node 5:
# 	Count = 133533.0	Rate = 0.9290437569739315
# 	['limited insulation', 'suspended, insulated', 'solid, insulated', 'other premises below|(eiddo arall islaw)', 'insulated']
#
#
#
# Variable: WINDOWS_DESCRIPTION
# p-value: 0.0
# Chi2: 643425.8263602206
#
# Node 1:
# 	Count = 5514.0	Rate = 0.9309031556039173
# 	['<missing>']
#
# Node 2:
# 	Count = 394874.0	Rate = 0.9927445210370903
# 	['partial double glazing|partial double glazing', 'multiple glazing throughout|multiple glazing throughout', 'high performance glazing|high performance glazing', 'high performance glazing', 'full double glazing|full double glazing']
#
# Node 3:
# 	Count = 205682.0	Rate = 0.05081144679651112
# 	['mostly double glazing', 'some triple glazing', 'partial secondary glazing', 'single glazing and secondary glazing', 'mostly multiple glazing', 'mostly secondary glazing', 'partial multiple glazing', 'partial double glazing', 'some double glazing', 'single and multiple glazing', 'solid, no insulation (assumed)', 'suspended, no insulation (assumed)', 'single glazing|single glazing', 'gwydrau triphlyg gan mwyaf', 'some secondary glazing']
#
# Node 4:
# 	Count = 117590.0	Rate = 0.08975252997703886
# 	['secondary glazing', 'single glazing and double glazing', 'single glazing', 'some multiple glazing', 'partial triple glazing', 'double glazing', 'full secondary glazing']
#
# Node 5:
# 	Count = 1189174.0	Rate = 0.4526419178354051
# 	['unknown complex glazing regime', 'full triple glazing', 'full double glazing', 'mostly triple glazing', 'multiple glazing throughout']
#
#
#
# Variable: WINDOWS_ENERGY_EFF
# p-value: 0.0
# Chi2: 820025.4597001518
#
# Node 1:
# 	Count = 402748.0	Rate = 0.9915331671417362
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 234316.0	Rate = 0.059372812782737844
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 759003.0	Rate = 0.25415841571113684
# 	['Average']
#
# Node 4:
# 	Count = 516767.0	Rate = 0.6777909580139598
# 	['Good']
#
#
#
# Variable: WINDOWS_ENV_EFF
# p-value: 0.0
# Chi2: 820025.4597001518
#
# Node 1:
# 	Count = 402748.0	Rate = 0.9915331671417362
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 234316.0	Rate = 0.059372812782737844
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 759003.0	Rate = 0.25415841571113684
# 	['Average']
#
# Node 4:
# 	Count = 516767.0	Rate = 0.6777909580139598
# 	['Good']
#
#
#
# Variable: WALLS_DESCRIPTION
# p-value: 0.0
# Chi2: 1238750.4159884637
#
# Node 1:
# 	Count = 173529.0	Rate = 0.9863769168265824
# 	['<missing>', 'average thermal transmittance 0.0 w/m²k', 'average thermal transmittance 0.3 w/m²k']
#
# Node 2:
# 	Count = 50645.0	Rate = 0.3198341395991707
# 	['average thermal transmittance 1.5 w/m²k', 'average thermal transmittance 1.3 w/m²k', 'average thermal transmittance 1.4 w/m²k', 'average thermal transmittance 1.6 w/m²k', 'cob, insulated', 'cavity wall, partial insulation', 'average thermal transmittance 1.1 w/m²k', 'sandstone, filled cavity', 'solid brick, partial insulation', 'average thermal transmittance 2.3 w/m²k', 'average thermal transmittance 1.7 w/m²k', 'timber frame, partial insulation']
#
# Node 3:
# 	Count = 320685.0	Rate = 0.055057143302617836
# 	['cob, as built', 'cavity wall,', 'average thermal transmittance 2.0 w/m²k', 'cavity wall, no insulation', 'system built, no insulation', 'average thermal transmittance 2.2 w/m²k', 'average thermal transmittance 1.8 w/m²k', 'sandstone or limestone, partial insulation', 'granite or whinstone, partial insulation', 'average thermal transmittance 2.1 w/m²k', 'sandstone, partial insulation']
#
# Node 4:
# 	Count = 299791.0	Rate = 0.5216734324913023
# 	['granite or whinstone, insulated', 'average thermal transmittance 1.2 w/m²k', 'sandstone or limestone, insulated', 'cavity wall, filled cavity', 'system built, partial insulation', 'average thermal transmittance 2.4 w/m²k', 'system built, filled cavity', 'sandstone, insulated', 'average thermal transmittance 0.9 w/m²k', 'average thermal transmittance 0.7 w/m²k', 'average thermal transmittance 0.8 w/m²k', 'average thermal transmittance 1.0 w/m²k', 'solid brick, insulated']
#
# Node 5:
# 	Count = 422207.0	Rate = 0.02737756598066825
# 	['average thermal transmittance 2.8 w/m²k', 'average thermal transmittance 2.6 w/m²k', 'average thermal transmittance 2.5 w/m²k', 'average thermal transmittance 3.2 w/m²k', 'cob,', 'cob, internal', 'average thermal transmittance 6.3 w/m²k', 'average thermal transmittance 2.7 w/m²k', 'average thermal transmittance 3.0 w/m²k', 'park home wall, as built', 'granite or whinstone, no insulation', 'park home wall, insulated', 'average thermal transmittance 1.9 w/m²k', 'sandstone or limestone, no insulation', 'timber frame, no insulation', 'sandstone, no insulation', 'solid brick, no insulation']
#
# Node 6:
# 	Count = 377184.0	Rate = 0.8364432213455502
# 	['average thermal transmittance 0.5 w/m²k', 'timber frame, filled cavity', 'cavity wall, filled cavity and external insulation', 'cavity wall, filled cavity and internal insulation', 'cavity wall, insulated', 'timber frame, insulated', 'solid brick, filled cavity', 'average thermal transmittance 0.6 w/m²k', 'average thermal transmittance 0.4 w/m²k', 'system built, insulated']
#
# Node 7:
# 	Count = 268793.0	Rate = 0.9968749186176723
# 	['average thermal transmittance 0.2 w/m²k', 'average thermal transmittance 0.1 w/m²k', 'granite or whinstone,', 'cob, filled cavity', 'average thermal transmittance nan w/m²k']
#
#
#
# Variable: WALLS_ENERGY_EFF
# p-value: 0.0
# Chi2: 1188207.7241871937
#
# Node 1:
# 	Count = 432887.0	Rate = 0.9920187023403336
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 322749.0	Rate = 0.058646192552107054
# 	['Poor']
#
# Node 3:
# 	Count = 110043.0	Rate = 0.35555192061285135
# 	['Average']
#
# Node 4:
# 	Count = 629680.0	Rate = 0.7282810316351163
# 	['Good']
#
# Node 5:
# 	Count = 417475.0	Rate = 0.02478471764776334
# 	['Very Poor']
#
#
#
# Variable: WALLS_ENV_EFF
# p-value: 0.0
# Chi2: 1188207.7241871937
#
# Node 1:
# 	Count = 432887.0	Rate = 0.9920187023403336
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 322749.0	Rate = 0.058646192552107054
# 	['Poor']
#
# Node 3:
# 	Count = 110043.0	Rate = 0.35555192061285135
# 	['Average']
#
# Node 4:
# 	Count = 629680.0	Rate = 0.7282810316351163
# 	['Good']
#
# Node 5:
# 	Count = 417475.0	Rate = 0.02478471764776334
# 	['Very Poor']
#
#
#
# Variable: ROOF_DESCRIPTION
# p-value: 0.0
# Chi2: 989153.0469893228
#
# Node 1:
# 	Count = 110261.0	Rate = 0.9722658056792519
# 	['<missing>', 'average thermal transmittance 0.0 w/m²k', 'average thermal transmittance 0.2 w/m²k']
#
# Node 2:
# 	Count = 277525.0	Rate = 0.006082334924781551
# 	['Pitched, 11mm loft insulation', 'Pitched, 1mm loft insulation', 'average thermal transmittance 3.6 w/m²k', 'Roof room(s)', 'Pitched,mm loft insulation', 'average thermal transmittance 2.6 w/m²k', 'average thermal transmittance 5.0 w/m²k', 'Roof room(s), thatched, with additional insulation', 'average thermal transmittance 2.1 w/m²k', 'average thermal transmittance nan w/m²k', 'average thermal transmittance 2.8 w/m²k', 'average thermal transmittance 2.5 w/m²k', 'average thermal transmittance 0.9 w/m²k', 'average thermal transmittance 2.4 w/m²k', 'average thermal transmittance 4.2 w/m²k', 'Roof room(s), no insulation', 'Pitched, 12mm loft insulation', 'Pitched, no insulation', 'Roof room(s), limited insulation', 'Pitched, 25mm loft insulation', 'Flat, no insulation']
#
# Node 3:
# 	Count = 149663.0	Rate = 0.07567668695669605
# 	['Flat, limited insulation', 'average thermal transmittance 2.3 w/m²k', 'Pitched, loft insulation', 'average thermal transmittance 1.8 w/m²k', 'Pitched, 75mm loft insulation', 'Pitched, limited insulation', 'Roof room(s), thatched with additional insulation', 'Pitched, 50mm loft insulation', 'Roof room(s), thatched', 'Pitched, Unknown loft insulation', 'Thatched, with additional insulation', 'Thatched', 'Pitched, 0mm loft insulation']
#
# Node 4:
# 	Count = 122048.0	Rate = 0.2980302831672784
# 	['average thermal transmittance 1.2 w/m²k', 'Pitched, insulated at rafters', 'Pitched, 150mm loft insulation', 'average thermal transmittance 1.9 w/m²k', 'average thermal transmittance 0.5 w/m²k', 'Flat', 'average thermal transmittance 0.6 w/m²k', 'average thermal transmittance 1.0 w/m²k']
#
# Node 5:
# 	Count = 189499.0	Rate = 0.16197974659496883
# 	['average thermal transmittance 2.0 w/m²k', 'average thermal transmittance 0.8 w/m²k', 'Pitched,  loft insulation', 'Pitched, 100mm loft insulation', 'Roof room(s), ceiling insulated']
#
# Node 6:
# 	Count = 34141.0	Rate = 0.5764623180340354
# 	['average thermal transmittance 1.4 w/m²k', 'Roof room(s), insulated', 'Pitched, 400+mm loft insulation', 'Flat, insulated', 'Pitched', 'average thermal transmittance 0.4 w/m²k']
#
# Node 7:
# 	Count = 383165.0	Rate = 0.4678689337491681
# 	['Pitched, 300mm loft insulation', 'average thermal transmittance 1.6 w/m²k', 'average thermal transmittance 1.5 w/m²k', 'Pitched, Joists loft insulation', 'average thermal transmittance 2.2 w/m²k', 'Thatched, insulated at rafters', 'average thermal transmittance 0.7 w/m²k', 'Pitched, 400mm loft insulation', 'Pitched, 350mm loft insulation', 'Pitched, 300+mm loft insulation', 'Pitched, 250mm loft insulation', 'Pitched, 270mm loft insulation', 'average thermal transmittance 1.3 w/m²k', 'Pitched, 200mm loft insulation', 'average thermal transmittance 1.1 w/m²k']
#
# Node 8:
# 	Count = 367497.0	Rate = 0.7943765527337638
# 	['Pitched, insulated', 'average thermal transmittance 0.3 w/m²k', '(other premises above)']
#
# Node 9:
# 	Count = 279035.0	Rate = 0.9971795652875087
# 	['average thermal transmittance 0.1 w/m²k', 'Pitched, Flat Roof Insulation loft insulation', 'Roof room(s), loft insulation', "Pitched, Don't know loft insulation"]
#
#
#
# Variable: ROOF_ENERGY_EFF
# p-value: 0.0
# Chi2: 811383.5216326388
#
# Node 1:
# 	Count = 310664.0	Rate = 0.8076925553009039
# 	['<missing>']
#
# Node 2:
# 	Count = 94198.0	Rate = 0.060670077920974966
# 	['Poor']
#
# Node 3:
# 	Count = 254793.0	Rate = 0.15480409587390548
# 	['Average']
#
# Node 4:
# 	Count = 578744.0	Rate = 0.5576213317114302
# 	['Good']
#
# Node 5:
# 	Count = 385041.0	Rate = 0.8707799948576905
# 	['Very Good']
#
# Node 6:
# 	Count = 289394.0	Rate = 0.008058218207702993
# 	['Very Poor']
#
#
#
# Variable: ROOF_ENV_EFF
# p-value: 0.0
# Chi2: 811383.5216326388
#
# Node 1:
# 	Count = 310664.0	Rate = 0.8076925553009039
# 	['<missing>']
#
# Node 2:
# 	Count = 94198.0	Rate = 0.060670077920974966
# 	['Poor']
#
# Node 3:
# 	Count = 254793.0	Rate = 0.15480409587390548
# 	['Average']
#
# Node 4:
# 	Count = 578744.0	Rate = 0.5576213317114302
# 	['Good']
#
# Node 5:
# 	Count = 385041.0	Rate = 0.8707799948576905
# 	['Very Good']
#
# Node 6:
# 	Count = 289394.0	Rate = 0.008058218207702993
# 	['Very Poor']
#
#
#
# Variable: MAINHEAT_ENERGY_EFF
# p-value: 0.0
# Chi2: 313016.19191422005
#
# Node 1:
# 	Count = 135889.0	Rate = 0.8817343567176151
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 245792.0	Rate = 0.22779016404114047
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 302835.0	Rate = 0.18392854194528374
# 	['Average']
#
# Node 4:
# 	Count = 1228318.0	Rate = 0.590164761893907
# 	['Good']
#
#
#
# Variable: MAINHEAT_ENV_EFF
# p-value: 0.0
# Chi2: 280746.6787413579
#
# Node 1:
# 	Count = 162472.0	Rate = 0.8564306465113989
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 320062.0	Rate = 0.286950653310921
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 146197.0	Rate = 0.043947550223328795
# 	['Average']
#
# Node 4:
# 	Count = 1284103.0	Rate = 0.5599270463506432
# 	['Good']
#
#
#
# Variable: MAINHEATCONT_DESCRIPTION
# p-value: 0.0
# Chi2: 755600.3186609687
#
# Node 1:
# 	Count = 328495.0	Rate = 0.9819814609050366
# 	['<missing>', 'Unit charging, programmer and TRVs', 'Flat rate charging, programmer and at least two room thermostats', 'Time and temperature zone control', 'Charging system linked to use of community heating, TRVs', "Delayed start stat & program & TRV's", 'Flat rate charging*, programmer and TRVs', 'Charging system linked to use of community heating, programmer and TRVs', 'Programmer, roomstat and TRVs', 'Charging system linked to use of community heating, programmer and at least two room thermostats', 'Not applicable (boiler provides DHW only)', "TRV's, program & flow switch", '2207 Time and temperature zone control', 'Charging system linked to use of community heating, programmer', 'TÃ¢l un gyfradd, TRVs', 'Delayed start thermostat, programmer and TRVs', 'Programmer and delayed start thermostat', 'Charging system linked to use of communit heating, programmer and room thermostat', 'Programmer and at least two room thermostats including a delayed start thermostat', 'Delayed start thermostat and programmer', 'Charging system linked to use of communit heating, room thermostat only', 'Thermostat, programmer and TRVs', 'Charging linked to use, programmer and TRVs', 'Charging system linked to use of community heating, programmer and at least two room stats']
#
# Node 2:
# 	Count = 38744.0	Rate = 0.9173549452818501
# 	['Flat rate charging, programmer and room thermostat', 'Charging system linked to the use of community heating, programmer and TRVs', 'Charging system linked to use of communit heating, TRVs', 'Charging system linked to use of community heating, room thermostat only', 'Flat rate charging, TRVs', 'Programmer, TRVs and flow switch', 'Celect controls', 'Charging system linked to use of community heating, programmer and room thermostat', 'Flat rate charging, no thermostatic control of room temperature', 'Celect control', 'Charging system linked to use of community heating, programmerand room thermostat', 'Charging system linked to the use of community heating, prog and TRVs', 'Flat rate charging, programmer and TRVs', 'Flat rate charging, programmer no room thermostat', 'Flat rate charging, programmer and room stat', 'Celect-type controls', 'Flat rate charging, room thermostat only', 'Charging system linked to use of community heating, programmer?and TRVs', 'Flat rate charging, no stat control of room temperature']
#
# Node 3:
# 	Count = 147588.0	Rate = 0.01757595468466271
# 	['Programmer, no room thermostat', 'Not relevant (supplies DHW only)', 'No time or thermostatic control of room temp', 'No time or thermostatic control of room temperature', 'No thermostatic control of room temperature', 'Appliance thermostat', 'Rhaglennydd, TRVs a falf osgoi', 'Programmer, no thermostat', 'Dim rheolaeth amser na rheolaeth thermostatig ar dymheredd yr ystafell', 'Rheoli’r tâl â llaw', 'Rhaglennydd a thermostatau ar y cyfarpar', 'Dim rheolaeth thermostatig ar dymheredd yr ystafell', 'Rhaglennydd a thermostat ystafell', 'Rheoli?r tal a llaw', 'None']
#
# Node 4:
# 	Count = 727647.0	Rate = 0.6214249491855254
# 	['Charging system linked to use of communit heating, programmer and TRVs', 'Flat rate charging, programmer, no room thermostat', 'Flat rate charging, no thermostatic control', 'Programmer and at least two room thermostats', 'Rhaglennydd, thermostat ystafell a TRVs', 'Programmer and room thermostats', 'Programmer, room thermostat and TRVs']
#
# Node 5:
# 	Count = 453401.0	Rate = 0.15369838178565992
# 	['Room thermostats only', 'Room thermostat only', 'Programmer and room thermostat', 'Programmer, TRVs and bypass', 'Appliance thermostats', 'TRVs and bypass']
#
# Node 6:
# 	Count = 86433.0	Rate = 0.4176414101095646
# 	['Thermostat and programmer', 'Temperature zone control', 'Appliance thermostat and programmer', 'Controls for high heat retention storage heaters', 'Programmer, TRVs and boiler energy manager', 'Automatic charge control', 'Programmer and at least 2 room thermostats', 'Programmer and appliance thermostats']
#
# Node 7:
# 	Count = 130526.0	Rate = 0.2891531189188361
# 	['Manual charge control']
#
#
#
# Variable: MAINHEATC_ENERGY_EFF
# p-value: 0.0
# Chi2: 541947.54378025
#
# Node 1:
# 	Count = 307135.0	Rate = 0.983333062008563
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 250183.0	Rate = 0.2416511113864651
# 	['Poor']
#
# Node 3:
# 	Count = 492861.0	Rate = 0.30756744802287056
# 	['Average']
#
# Node 4:
# 	Count = 744139.0	Rate = 0.5855088901401485
# 	['Good']
#
# Node 5:
# 	Count = 118516.0	Rate = 0.05616119342536029
# 	['Very Poor']
#
#
#
# Variable: MAINHEATC_ENV_EFF
# p-value: 0.0
# Chi2: 541947.54378025
#
# Node 1:
# 	Count = 307135.0	Rate = 0.983333062008563
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 250183.0	Rate = 0.2416511113864651
# 	['Poor']
#
# Node 3:
# 	Count = 492861.0	Rate = 0.30756744802287056
# 	['Average']
#
# Node 4:
# 	Count = 744139.0	Rate = 0.5855088901401485
# 	['Good']
#
# Node 5:
# 	Count = 118516.0	Rate = 0.05616119342536029
# 	['Very Poor']
#
#
#
# Variable: LIGHTING_ENERGY_EFF
# p-value: 0.0
# Chi2: 357980.29060032085
#
# Node 1:
# 	Count = 927017.0	Rate = 0.714386036070536
# 	['<missing>', 'Very Good']
#
# Node 2:
# 	Count = 435626.0	Rate = 0.20490971613264589
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 550191.0	Rate = 0.37242521233535264
# 	['Average', 'Good']
#
#
#
# Variable: LIGHTING_ENV_EFF
# p-value: 0.0
# Chi2: 359475.1660807411
#
# Node 1:
# 	Count = 4993.0	Rate = 0.9751652313238534
# 	['<missing>']
#
# Node 2:
# 	Count = 435775.0	Rate = 0.20494521255234927
# 	['Poor', 'Very Poor']
#
# Node 3:
# 	Count = 550438.0	Rate = 0.37247610085059535
# 	['Average', 'Good']
#
# Node 4:
# 	Count = 921628.0	Rate = 0.7131000794246702
# 	['Very Good']
#
#
#
# Variable: MAIN_FUEL
# p-value: 0.0
# Chi2: 475114.0753588026
#
# Node 1:
# 	Count = 94084.0	Rate = 0.9001849411164491
# 	['<missing>', 'Gas: bottled LPG', 'Solid fuel: wood logs', 'B30D (community)', 'Gas: bulk LPG', 'Oil: heating oil', 'coal (community)', 'mains gas (community)', 'electricity (community)', 'Solid fuel: wood pellets (bulk supply in bags, for main heating)', 'Electricity: electricity, unspecified tariff']
#
# Node 2:
# 	Count = 206421.0	Rate = 0.3043440347639048
# 	['electricity (not community)', 'oil (community)', 'LPG - this is for backwards compatibility only and should not be used']
#
# Node 3:
# 	Count = 46685.0	Rate = 0.007282853164828103
# 	['bottled LPG', 'LPG (not community)', 'house coal (not community)', 'To be used only when there is no heating/hot-water system', 'smokeless coal', 'biodiesel from any biomass source', 'appliances able to use mineral oil or liquid biofuel', 'heat from boilers that can use mineral oil or biodiesel (community)', 'bioethanol', 'biogas (not community)', 'B30K', 'wood pellets in bags for secondary heating', 'To be used only when there is no heating/hot-water system or data is from a community network', 'dual fuel - mineral + wood', 'house coal - this is for backwards compatibility only and should not be used']
#
# Node 4:
# 	Count = 698054.0	Rate = 0.3882923097640011
# 	['from heat network data (community)', 'waste combustion (community)', 'biomass - this is for backwards compatibility only and should not be used', 'biomass (community)', 'mains gas (not community)', 'LPG special condition']
#
# Node 5:
# 	Count = 74119.0	Rate = 0.9997706391073814
# 	['Solid fuel: dual fuel appliance (mineral and wood)', 'Electricity: electricity displaced from grid', 'biodiesel from vegetable oil only', 'LPG subject to Special Condition 18', 'biogas (community)', 'Community heating schemes: heat from boilers - biomass', 'Solid fuel: wood chips', 'Community heating schemes: heat from heat pump', 'waste combustion - this is for backwards compatibility only and should not be used', 'Gas: mains gas']
#
# Node 6:
# 	Count = 601794.0	Rate = 0.7260590833408109
# 	['LPG (community)', 'mains gas - this is for backwards compatibility only and should not be used', 'biogas - landfill - this is for backwards compatibility only and should not be used', 'wood chips', 'heat from boilers using biodiesel from any biomass source (community)']
#
# Node 7:
# 	Count = 101450.0	Rate = 0.21857072449482504
# 	['anthracite', 'oil - this is for backwards compatibility only and should not be used', 'electricity - this is for backwards compatibility only and should not be used']
#
# Node 8:
# 	Count = 90227.0	Rate = 0.04763540846974852
# 	['bulk wood pellets', 'B30K (not community)', 'oil (not community)', 'wood logs']
#
#
#
# Variable: HEAT_LOSS_CORRIDOR
# p-value: 0.0
# Chi2: 92418.49967178737
#
# Node 1:
# 	Count = 1482870.0	Rate = 0.45056410878903747
# 	['<missing>']
#
# Node 2:
# 	Count = 132499.0	Rate = 0.5388040664457845
# 	['no corridor']
#
# Node 3:
# 	Count = 96709.0	Rate = 0.888986547270678
# 	['heated corridor']
#
# Node 4:
# 	Count = 200756.0	Rate = 0.6521598358205981
# 	['unheated corridor']
#
#
#
# Variable: MECHANICAL_VENTILATION
# p-value: 0.0
# Chi2: 570919.6050332859
#
# Node 1:
# 	Count = 460780.0	Rate = 0.9849125396067537
# 	['<missing>']
#
# Node 2:
# 	Count = 1452054.0	Rate = 0.34612280259549577
# 	['mechanical, extract only', 'natural', 'mechanical, supply and extract']
#
#
#
# Variable: SECONDHEAT_DESCRIPTION
# p-value: 0.0
# Chi2: 630384.840463671
#
# Node 1:
# 	Count = 10574.0	Rate = 0.9837336864006052
# 	['<missing>', 'Room heaters, liquid biofuel', 'Room heaters, appliances able to use mineral oil or liquid biofuel', 'Room heaters, |Gwresogyddion ystafell, |mains gas|nwy prif gyflenwad', 'Room heaters, |Gwresogyddion ystafell, |wood chips|asglodion coed', 'Room heaters, dual fuel', 'Room heaters, |Gwresogyddion ystafell, |wood pellets|pelenni coed', 'None|Dim', 'Room heaters, |Gwresogyddion ystafell, |wood logs|logiau coed', 'Room heaters', 'Room heaters, |Gwresogyddion ystafell, |electric|trydan']
#
# Node 2:
# 	Count = 219148.0	Rate = 0.2982596236333437
# 	['Room heaters, electric', 'Electric Underfloor Heating (Standard tariff), electric', 'Gas (including LPG) room heaters, gas']
#
# Node 3:
# 	Count = 151919.0	Rate = 0.0493486660654691
# 	['Room heaters, oil', 'Room heaters, anthracite', 'Room heaters,', 'Room heaters, dual fuel (mineral and wood)', 'Gwresogyddion ystafell, logiau coed', 'LPG room heaters, gas', 'Gas/LPG boiler pre-1998, with fan-assisted flue, gas', 'Room heaters, LNG', 'Room heaters, main wood pellets', 'Room heaters, wood pellets (bags)', 'Room heaters, heating oil', 'Gwresogyddion ystafell, nwy prif gyflenwad', 'Room heaters, secondary wood pellets', 'Mains Gas room heaters, gas', 'Gwresogyddion ystafell, tanwydd di-fwg', 'Room heaters, bulk LPG', 'Room heaters, bottled LPG', ',', 'Room heaters, B30K', 'Gwresogyddion ystafell, glo', 'Electric ceiling heating', 'Other Space Heating Systems, electric', 'Hot-Water-Only Systems, gas', 'Hot-Water-Only Systems, electric', 'Gwresogyddion ystafell, trydan', 'Gas/LPG boiler pre-1998 with balanced or open-flue, gas', 'Room heaters, lpg', 'Room heaters, smokeless fuel', 'Room heaters, coal', 'Room heaters, LPG', 'Room heaters, bottled gas']
#
# Node 4:
# 	Count = 1059964.0	Rate = 0.7459470321633564
# 	['Room heaters, biodiesel from any biomass source', 'Room heaters, (null)', 'Room heaters, wood pellets', 'Portable electric heaters(assumed)', 'Room heaters, bioethanol', 'Dim', 'Room heaters, bulk wood pellets', 'None', 'Room heaters, ']
#
# Node 5:
# 	Count = 282072.0	Rate = 0.1293251368444936
# 	['Room heaters, mains gas', 'Gas/LPG boiler 1998 or later, gas', 'Portable electric heaters']
#
# Node 6:
# 	Count = 189157.0	Rate = 0.24317894658934114
# 	['Room heaters, wood logs', 'Room heaters, wood chips', 'Portable electric heaters (assumed)']
#
#
#
# Variable: LIGHTING_DESCRIPTION
# p-value: 0.0
# Chi2: 437022.24764417415
#
# Node 1:
# 	Count = 671019.0	Rate = 0.8049086538533186
# 	['<missing>', 'low energy lighting in all fixed outlets']
#
# Node 2:
# 	Count = 141315.0	Rate = 0.5100024767363691
# 	['low energy lighting 100% of fixed outlets', 'low energy lighting 80% of fixed outlets']
#
# Node 3:
# 	Count = 466577.0	Rate = 0.36597389069756975
# 	['low energy lighting 40% of fixed outlets', 'low energy lighting 30% of fixed outlets', 'low energy lighting 60% of fixed outlets', 'low energy lighting 50% of fixed outlets']
#
# Node 4:
# 	Count = 329619.0	Rate = 0.19335657228497144
# 	['low energy lighting 0% of fixed outlets', 'goleuadau ynni-isel ym mhob un ogçör mannau gosod', 'low energy lighting 10% of fixed outlets', 'no low energy lighting']
#
# Node 5:
# 	Count = 158862.0	Rate = 0.42944820032481024
# 	['low energy lighting 90% of fixed outlets', 'low energy lighting 70% of fixed outlets']
#
# Node 6:
# 	Count = 145442.0	Rate = 0.28550900015126307
# 	['low energy lighting 20% of fixed outlets']

# %%
# %store chaid_dict
# Out:
# Stored 'chaid_dict' (dict)
